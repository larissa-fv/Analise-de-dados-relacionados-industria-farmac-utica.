# %% [markdown]
# <a href="https://colab.research.google.com/github/larissa-fv/Copia_aula_dados/blob/main/Imers%C3%A3o_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Analise de dados relacionados à industria farmacêutica.**
#
#  *Para isso nós utilizamos uma biblioteca muito conhecida no mundo de DataScience: o Pandas.*

# %%
import pandas as pd

url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
dados = pd.read_csv(url_dados, compression = "zip")

dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados["tratamento"]
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# com o ultimo dado analisado, podemos concluir que: um gene ao possuir um rna mensageiro, o mesmo pode sofrer uma alterção com um determinado estimulo (nesse caso, a droga)

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# **Valores representado em gráficos**

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %% [markdown]
# ***Gráfico para a analise de dados de tipos de tratamento***

# %%
dados['tratamento'].value_counts().plot.bar()

# %% [markdown]
# ***Gráfico para analisar o tempo de respostas dos genes à droga***

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# Dados do g-0 com o valor > 0

# %%
dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados[dados['g-0'] > 0]
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# Filtragem de dados do g-0 com o valor > 0

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 01: Instigar por que a classe tratamento é tão desbalanceada.

# %% [markdown]
# ###Desafio 02: Plotar as cinco últimas linhas da tabela

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 03: Calcular a proporção das clasees de tratamento

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tratamento'].value_counts().plot.bar()

# %% [markdown]
# ###Desafio 04: Quantas tipos de drogas foram investigados

# %%
dados['droga'].unique().shape[0]
# Out:
# 3289

# %% [markdown]
# outra opção seria:

# %%
len(dados['droga'].unique())
# Out:
# 3289

# %% [markdown]
# ###Desafio 05: Procurar na documentação o metodo query

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %% [markdown]
# ###Desafio 06: Renomear as colunas tirando o hífen

# %%
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g-0', 'g-1', 'g-2',
#        'g-3', 'g-4',
#        ...
#        'c-90', 'c-91', 'c-92', 'c-93', 'c-94', 'c-95', 'c-96', 'c-97', 'c-98',
#        'c-99'],
#       dtype='object', length=877)

# %%
nome_das_colunas = dados.columns

# %%
novo_nome_coluna = []
for coluna in nome_das_colunas:
  coluna = coluna.replace('-','_')
  novo_nome_coluna.append(coluna)
dados.columns = novo_nome_coluna
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 07: Como deixar os gráficos bonitos

# %%
import matplotlib.pyplot as plt

# %%
valore_tempo = dados['tempo'].value_counts(ascending = True)
valore_tempo.sort_index()
# Out:
# 24    7772
# 48    8250
# 72    7792
# Name: tempo, dtype: int64

# %%
plt.figure(figsize=(15, 10))
valore_tempo = dados['tempo'].value_counts(ascending=True)
ax = valore_tempo.sort_index().plot.bar()
ax.set_title('Janelas de tempo', fontsize=20)
ax.set_xlabel('Tempo', fontsize=18)
ax.set_ylabel('Quantidade', fontsize=18)
plt.xticks(rotation = 0, fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %% [markdown]
# ##**Aula 2**

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# *mudando o nome da coluna*

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace = True)

# %% [markdown]
# importante colocar o parametro 'inplace', pois isso siginifica: "troca esse valor por um novo que você criou"

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Sebbarn

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
#  O countplot é um gráfico pré-programado da biblioteca Seaborne, por isso, precisaremos fazer a importação padrão

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
len(dados['g_0'].unique())
# Out:
# 14367

# %%
dados['g_0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()

# %% [markdown]
# *vamos ver um exemplo de histogram*

# %%
dados['g-0'].hist(bins = 60)

# %%
dados['g-10'].hist(bins = 60)

# %%
dados.describe()

# %% [markdown]
# como selecionar dois elementos:

# %%
dados[{'g-0','g-1'}]

# %%
dados.loc[:,'g-0' : 'g-771'].describe()

# %% [markdown]
# histogram da  linha media do gene 1 até o 771

# %%
dados.loc[:,'g-0':'g-771'].describe().T['mean'].hist(bins=30)

# %% [markdown]
# Alterando o parâmetro estatístico a ser analisado (mínimo e máximo, por exemplo).

# %% [markdown]
# assim, pode-se perceber as niances de cada métricas

# %%
dados.loc[:,'g-0':'g-771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:,'g-0':'g-771'].describe().T['max'].hist(bins=30)

# %% [markdown]
# Da mesma forma que analisamos os genes (g), vamos agora analisar os tipos celulares (c).

# %%
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins = 50)

# %% [markdown]
# ###Boxplot é outro tipo de grafico super interessante.
#
#  O boxplot apresenta uma caixa no meio onde podemos identificar a mediana

# %%
sns.boxplot(x='g_0' , data=dados)

# %% [markdown]
# no bosplot anterior definimos os dados para o eixo x.
#  Agora, iremos definir os dados para o eixo y

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g_0', x='tratamento' , data=dados)

# %% [markdown]
# ###Desafio 01: Ordenar o gráfico countplot

# %% [markdown]
# o cod_compostos já está ordenado. Então podemos utilizar ele.

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order=cod_compostos)
ax.set_title('Top 5 compostos')
plt.show()

# %% [markdown]
# ###Desafio 02: Melhorar a visualização alterando tamanho da fonte

# %%
sns.set()
          
plt.rc('axes', titlesize=14)     # O tamanho da fonte do título
plt.rc('axes', labelsize=14)    # O tamanho da fonte dos eixos x e y
plt.rc('xtick', labelsize=14)    # O tamanho da fonte dos números e texto no eixo x
plt.rc('ytick', labelsize=14)    # O tamanho da fonte dos números e texto no eixo y
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order=cod_compostos)
ax.set_title('Top 5 compostos')
ax.set_ylabel('Contagem')
ax.set_xlabel('Composto')
plt.show()

# %% [markdown]
# ###Desafio 03: Plotar os histogramas com seaborn

# %%
dados['tratamento'].hist(bins=10)

# %%
dados['g_0'].hist(bins=50)

# %%
dados['c_0'].hist(bins = 10)

# %%
dados['g_29'].hist(bins = 50)

# %%
dados.loc[:,'g_0':'g_771'].describe().T['max'].hist(bins=30)

# %%
sns.histplot(data=dados.loc[:,'c_0':'c_99'].describe().T['mean'],bins=50) # Versão com o Seaborn

# %% [markdown]
# ###Desafio 04: Um pouco mais sobre as estatíticas retornadas no .describe()

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

# %% [markdown]
# ###Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.

# %% [markdown]
# ###Desafio 06: Fazer outras análises com o boxplot e até com o histograma.

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g_0', x='dose' , data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g_0', x='tratamento' , data=dados)

# %% [markdown]
# Histogram de g_0 comparado com droga e com controle

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=dados, x='g_0', bins=100, hue='tratamento')
plt.show()
